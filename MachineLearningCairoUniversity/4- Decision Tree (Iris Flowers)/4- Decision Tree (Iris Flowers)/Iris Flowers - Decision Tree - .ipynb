# %%
import pandas as pd 
from sklearn import tree
from sklearn.model_selection import train_test_split

dataset  = pd.read_csv('irisflowers_string.csv')

X = dataset.drop("species" , axis =1 )
y = dataset["species"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
DT = tree.DecisionTreeClassifier(max_depth=2)
# DT.fit(X,y)
DT.fit(X_train,y_train)
DT.score(X_train,y_train)
# Out:
# 0.95

# %%
DT.score(X_test,y_test)
# Out:
# 0.98

# %%
X_test.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 73            6.1          2.8           4.7          1.2
# 18            5.7          3.8           1.7          0.3
# 118           7.7          2.6           6.9          2.3
# 78            6.0          2.9           4.5          1.5
# 76            6.8          2.8           4.8          1.4

# %%
DT.predict([X_test.loc[73]])
# Out:
# array(['versicolor'], dtype=object)

# %%
DT.predict_proba([X_test.loc[73]])
# Out:
# array([[0.        , 0.89473684, 0.10526316]])

# %%
plt.figure(figsize=(10,10))
plot_tree(DT, filled=True , rounded=True , feature_names= X.columns  , class_names=y.unique())
plt.show()

# %%
from sklearn.tree.export import export_text

r = export_text(DT , feature_names= 'petal length ' , 'petal width ')
print(r)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-213-c96a5b6cbff5> in <module>
#       1 from sklearn.tree.export import export_text
#       2
# ----> 3 r = export_text(DT , feature_names= X)
#       4 print(r)
#
# F:\Anaconda\lib\site-packages\sklearn\tree\export.py in export_text(decision_tree, feature_names, max_depth, spacing, decimals, show_weights)
#     876         raise ValueError("feature_names must contain "
#     877                          "%d elements, got %d" % (tree_.n_features,
# --> 878                                                   len(feature_names)))
#     879
#     880     if spacing <= 0:
#
# ValueError: feature_names must contain 4 elements, got 150
